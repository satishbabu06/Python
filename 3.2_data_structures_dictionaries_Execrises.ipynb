# %%
# Use the dictionary given below. This is a dictionary that shows the frequency of the words in a text paragraph. 
# The keys are the words, and the values are its frequency.
word_freq = {'love': 25, 'conversation': 1, 'every': 6, "we're": 1, 'plate': 1, 'sour': 1, 'jukebox': 1, 'now': 11, 'taxi': 1, 'fast': 1, 'bag': 1, 'man': 1, 'push': 3, 'baby': 14, 'going': 1, 'you': 16, "don't": 2, 'one': 1, 'mind': 2, 'backseat': 1, 'friends': 1, 'then': 3, 'know': 2}
print("key-value pairs in the dictionary : ",len(word_freq))
print( "keys are present in the dictionary: ",word_freq.keys())
print(" frequency of friends in dictionary :",word_freq.get('friends'))
print(" frequency of taxi in dictionary :",word_freq.get('taxi'))
print(" frequency of jukebox in dictionary :",word_freq.get('jukebox'))
if 'begin'in word_freq:
    print("begin in the dictionary")
else:
    print("begin not in the dictionary")
word_freq['begin']=1
word_freq['start']=2
word_freq['over']=1
word_freq['body']=17
print(word_freq)
word_list = list(word_freq.keys())
print("first_element in the list is :",word_list[0])
print("last_element in the list is :",word_list[-1])
# Out:
# key-value pairs in the dictionary :  23
# keys are present in the dictionary:  dict_keys(['love', 'conversation', 'every', "we're", 'plate', 'sour', 'jukebox', 'now', 'taxi', 'fast', 'bag', 'man', 'push', 'baby', 'going', 'you', "don't", 'one', 'mind', 'backseat', 'friends', 'then', 'know'])
#  frequency of friends in dictionary : 1
#  frequency of taxi in dictionary : 1
#  frequency of jukebox in dictionary : 1
# begin not in the dictionary
# {'love': 25, 'conversation': 1, 'every': 6, "we're": 1, 'plate': 1, 'sour': 1, 'jukebox': 1, 'now': 11, 'taxi': 1, 'fast': 1, 'bag': 1, 'man': 1, 'push': 3, 'baby': 14, 'going': 1, 'you': 16, "don't": 2, 'one': 1, 'mind': 2, 'backseat': 1, 'friends': 1, 'then': 3, 'know': 2, 'begin': 1, 'start': 2, 'over': 1, 'body': 17}
# first_element in the list is : love
# last_element in the list is : body

# %%
# 2. Can a dictionary have two key-value pairs with the same key?
# No

# %%
# 3. Can a dictionary have two key-value pairs with the same value but different keys?
# yes
