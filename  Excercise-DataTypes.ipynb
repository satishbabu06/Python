# %%
# 1. Exercise - Data Types
# 1.1 For the given variables, use the type() function in Python to check their data types:
x1 = 1.1
print(x1)
type(x1)
# Out:
# 1.1
# float

# %%
# 1.1 For the given variables, use the type() function in Python to check their data types:
x2 = "Ironhack"
print(x2)
type(x2)
# Out:
# Ironhack
# str

# %%
# 1.1 For the given variables, use the type() function in Python to check their data types:
x3 = "1.1"
print(x3)
type(x3)
# Out:
# 1.1
# str

# %%
# 1.1 For the given variables, use the type() function in Python to check their data types:
x4 = True 
print(x4)
type(x4)
# Out:
# True
# bool

# %%
# 1.1 For the given variables, use the type() function in Python to check their data types:
x5 = "True"
print(x5)
type(x5)
# Out:
# True
# str

# %%
# 1.1 For the given variables, use the type() function in Python to check their data types:
x6 = -1
print(x6)
type(x6)
# Out:
# -1
# int

# %%
 # 2 What is the difference between the variables x1 and x3?
x1 = float
x3 = str

# %%
 # 3 What is the difference between the variables x1 and x3?
typo error

# %%
 # 4 What is the difference between the variables x4 and x5?
x4 = bool
x5 = str

# %%
 # 5 Substract x4 from x5. Explain what happens.
typo error

# %%
# 2. Exercise - Operators
x1 = input("Please enter an integer number: ")
type(x1)
# Out:
# Please enter an integer number:  7.9
# str

# %%
# 2. Exercise - Operators
x2 = input("Please enter another integer number: ")
type(x2)
# Out:
# Please enter another integer number:  6
# str

# %%
# Question 1:
x1 = int(input("Please enter an integer number: "))
x2 = int(input("Please enter another integer number: "))
print(x1)
print(x2)
type(x1)
type(x2)
# Out:
# Please enter an integer number:  5
# Please enter another integer number:  2
# 5
# 2
# int

# %%
# Question 2:
# Perform the following simple comparisons, using operators:
# Check if the two variables are equal.
x1 = 10
x2 = 5
x1 == x2
# Out:
# False

# %%
# Question 2:
# Perform the following simple comparisons, using operators:
# Check if x1 is greater than x2.
x1 = 10
x2 = 5
x1 > x2
# Out:
# True

# %%
# Question 2:
# Perform the following simple comparisons, using operators:
# Check if x2 is greater than x1.
x1 = 10
x2 = 5
x1 < x2
# Out:
# False

# %%
# Question 2:
# Perform the following simple comparisons, using operators:
# Check if x1 is not equal to x2
x1 = 10
x2 = 5
x1 != x2
# Out:
# True

# %%
# Question 2:
# Perform the following simple comparisons, using operators:
# Store the difference between x1 and x2 in another variable x3 (subtract the smaller number from the larger number).
x1 = 10
x2 = 5
x3 = x1 - x2
print(x3)
# Out:
# 5

# %%
# Question 2:
# Perform the following simple comparisons, using operators:
# Increment the smaller of the two variables (x1 and x2) with the difference. Use the shorthand addition operator for the same. 
# Again check if x1 and x2 are equal or not.
x1 = 10
x2 = 5
x3 = x1 - x2
x2 += x3
x1 == x2
# Out:
# True

# %%
# Question 3:
# Exercise - Concatenation
first_name = input( "enter the first_name: ")
last_name = input( "enter the last_name: ")
result = first_name + last_name
print("Hello,"+result+"!")
# Out:
# enter the first_name:  sa
# enter the last_name:  ba
# Hello,saba!
