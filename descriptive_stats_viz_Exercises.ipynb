# %%
# Let's start by importing pandas and reading the titanic dataset
import pandas as pd
import seaborn as sns

# We can read from an online URL
performance_data = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/prework_data/main/students_performance.csv")
print(performance_data.head())

selected_columns = performance_data[performance_data["math score"] < 50]
print(selected_columns)

sns.histplot(x='gender',data =performance_data)
sns.histplot(x='race/ethnicity',data =performance_data)
sns.histplot(x='parental level of education',data =performance_data)

sns.countplot(x='math score',data =performance_data)
sns.countplot(x='reading score',data =performance_data)
sns.countplot(x='writing score',data =performance_data)
plot.show()
