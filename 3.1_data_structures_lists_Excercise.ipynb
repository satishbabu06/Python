# %%
# 1. Exercises Given the list: lst = [1, 2, 34, 5, 3, 12, 9, 8, 67, 89, 98, 90, 39, 21, 45, 46, 23, 13]
lst = [1, 2, 34, 5, 3, 12, 9, 8, 67, 89, 98, 90, 39, 21, 45, 46, 23, 13]
print(len(lst))
first_element = lst[0]
print(first_element)
last_element = lst[ len(lst) -1]
print(last_element)
index = lst.index(90)
print(index)
print(lst[:8])
lst.append(100)
lst.append(110)
print(lst)
lst.sort()
print(lst)
# Out:
# 18
# 1
# 13
# 11
# [1, 2, 34, 5, 3, 12, 9, 8]
# [1, 2, 34, 5, 3, 12, 9, 8, 67, 89, 98, 90, 39, 21, 45, 46, 23, 13, 100, 110]
# [1, 2, 3, 5, 8, 9, 12, 13, 21, 23, 34, 39, 45, 46, 67, 89, 90, 98, 100, 110]

# %%
# 2. Write a program that searches for a specific element in a given list and returns its index. 
# If the element is not found, print a message indicating that it is not present in the list.
names = ["Alice", "Bob", "Charlie", "Dave"] 
search_name = "Bob" # Element to search in "names" list
if search_name in names:
    print("Name found")
else:
    print("Name not found")
# Out:
# Name found

# %%
# 3.Write a program that calculates the average of the elements in a given list. The list can contain both positive and negative numbers.
numbers = [2, -4, -6, 8, 10]
num = len(numbers)
avg = sum(numbers)/num
print(avg)
# Out:
# 2.0
