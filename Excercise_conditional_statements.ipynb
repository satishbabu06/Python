# %%
# 1.Write a program that prompts the user to enter two numbers and determines which number is larger or if they are equal.
x1 = int(input("Please enter an integer number: "))
x2 = int(input("Please enter another integer number: "))
if x1 > x2 :
    print( "x1 is greater = ",x1)
elif x1 == x2:
    print (" x1 and X2 are equal",x1,x2)
else:
    print( "x2 is greater =",x2)
# Out:
# Please enter an integer number:  9
# Please enter another integer number:  12
# x2 is greater = 12

# %%
# 2. Write a program that prompts the user to enter a numerical grade and prints the corresponding grade classification according 
# to the following criteria:

percentage = float(input("Enter the percentage: "))

if percentage >= 90:
    grade = "A"
elif percentage >= 80:
    grade = "B"
elif percentage >= 70:
    grade = "C"
elif percentage >= 60:
    grade = "D"
else:
    grade = "F"

print("Your grade is:", grade)
# Out:
# Enter the percentage:  56
# Your grade is: F

# %%
# 3. Write a program that prompts the user to enter a letter of the alphabet and determines whether it is a vowel or a consonant. Consider both uppercase and 
# lowercase letters.

character  = input( "Enter the character")
lower_character = character.lower()
if lower_character == 'a':
    print("lower_character is vowel'a'")
elif lower_character == 'e':
    print("lower_character is vowel 'e'")
elif lower_character == 'i':
    print("lower_character is vowel 'i'") 
elif lower_character == 'o':
    print("lower_character is vowel 'o'")
elif lower_character == 'u':
    print("lower_character is vowel 'u'") 
else:
    print( "lower_character is consonant")
# Out:
# Enter the character a
# lower_character is vowel'a'
